# %%
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # [Демо KarpovCourses Аналитик данных](https://stepik.org/course/74457/syllabus)

# %% [markdown]
# ## 1 Первый урок python для работы с данными
#
# [Документация pandas](https://pandas.pydata.org/docs/index.html)

# %% [markdown]
# ### 1.1 Введение
#
# Всем привет! :)
#
# Приветствуем вас на демоверсии специализации по анализу данных от KarpovCourses. Здесь вам доступны первые 3 урока из первого модуля нашего курса.
#
# **Учебные материалы**
#
# Несколько слов об организации курса. Большинство уроков содержат следующие материалы:
#
# - лекция
# - конспект занятия
# - задачки на отработку синтаксиса
# - минипроект
# - подсказки к заданиям
# - разбор домашнего задания
#
# На стэпике находятся конспекты, задачки на синтаксис и вопросы по проекту. В конспектах описан материал из лекций, а также присутствует новая информация, которая может помочь вам сделать домашнюю работу. Поэтому рекомендуем после просмотра лекции сначала закрепить знания конспектом, а затем приступать к домашней работе :)
#
# После выполнения задания или после закрытия дедлайна открывается доступ к разбору этого задания. Довольно часто там разбираются альтернативные варианты решения и темы, которых не было в лекции. Кроме того, ссылки на разборы доступны после правильного решения задания. Также они есть в подсказках в последнем пункте.
#
# Вопросы можно писать под заданиями, в полной версии вам будет доступна служба поддержки в Slack.
#
# **Глоссарий**
#
# **Python (питон)** – высокоуровневый язык программирования общего назначения, ориентированный на повышение производительности разработчика и читаемости кода. Мы будем использовать версию 3.7. [Документацию](https://docs.python.org/3.7/) читать не обязательно, но если вас интересует то, как именно он работает, тогда ссылка к вашим услугам :)
#
# **Hotkeys (хоткеи)** – дословно означает горячие клавиши или сочетания клавиш на клавиатуре для выполнения той или иной операции. Например,  Ctrl + C или Сtrl + V
#
# **Subset (cабсет)** – часть набора данных (таблицы)
#
# **ГА ([Google Аналитика](https://analytics.google.com/))** – бесплатный сервис, предоставляемый компанией Google для создания детальной статистики посещаемости веб-сайтов
#
# **ЯМ ([Яндекс Метрика](https://metrika.yandex.ru/))** – бесплатный интернет-сервис компании Яндекс, предназначенный для оценки посещаемости веб-сайтов и анализа поведения пользователей

# %% [markdown]
# ### 1.3 Конспект первого урока
#
# Оглавление урока
# Ссылки на стэпы с кусочками конспекта из этого урока:
#
# 1. [Хоткеи юпитер ноутбука](https://stepik.org/lesson/375660/step/2?unit=363410)
# 2. [Арифметика](https://stepik.org/lesson/375660/step/3?unit=363410)
# 3. [Типы данных](https://stepik.org/lesson/375660/step/4?unit=363410)
# 4. [Переменные](https://stepik.org/lesson/375660/step/5?unit=363410)
# 5. [Сравнения](https://stepik.org/lesson/375660/step/6?unit=363410)
# 6. [Операции над строками](https://stepik.org/lesson/375660/step/7?unit=363410)
# 7. [Списки](https://stepik.org/lesson/375660/step/8?unit=363410)
# 8. [Оформление кода и комментарии](https://stepik.org/lesson/375660/step/9?unit=363410)
# 9. [Использованные в уроке функции](https://stepik.org/lesson/375660/step/10?unit=363410)
# 10. [Условия](https://stepik.org/lesson/375660/step/11?unit=363410)
# 11. [Логические операторы](https://stepik.org/lesson/375660/step/12?unit=363410)
# 12. [Циклы](https://stepik.org/lesson/375660/step/13?unit=363410)
# 13. [Вложенные конструкции](https://stepik.org/lesson/375660/step/14?unit=363410)
# 14. [Форматирование строк](https://stepik.org/lesson/375660/step/15?unit=363410)
# 15. [Словари](https://stepik.org/lesson/375660/step/16?unit=363410)

# %% [markdown]
# ### 1.4 Задания первого урока

# %% [markdown]
# ⭐️Задание со звёздочкой!⭐️
#
# Реализуйте цикл, который пробегается по уже созданному списку workers со значениями как в 2-м и 6-м заданиях и выводит для каждого сотрудника следующую строку (то есть печатает её для каждого элемента списка):
#
# user_name user_family is position
# где user_name и user_family — имя и фамилия сотрудника, а position — одна из следующих строк:
#
# - 'junior' — стаж меньше 2 лет
# - 'middle' — стаж больше либо равен 2
# - 'senior' — стаж строго больше 5 лет
#
# Пример данных, которые могут быть в workers:
#
# workers = [['Ivan', 'Ivanov', 100000, 2], ['Petr', 'Petrov', 150000, 2], ['Sidor', 'Sidorov', 200000, 3]]
#
# Note: в этом задании эти строки нужно печатать

# %%
workers = [['Ivan', 'Ivanov', 100000, 2], \
           ['Petr', 'Petrov', 150000, 2], \
           ['Sidor', 'Sidorov', 200000, 3]]
    
for i in workers:
    status = f'{i[0]} {i[1]} is '
    if i[3] < 2:
        status += 'junior'
    elif 2 <= i[3] <=5:
        status += 'middle'
    else:
        status += 'senior'
    print(status)
# Out:
# Ivan Ivanov is middle
# Petr Petrov is middle
# Sidor Sidorov is middle

# %% [markdown]
# ## 2 Второй урок python для работы с данными

# %% [markdown]
# ## 2.1 Лекция второго урока
#
# Теперь мы вплотную подобрались к стандартному способу анализа данных в Python. Мы научимся считывать и записывать данные, а также освоим ряд методов процессинга. Кроме того, убедимся в важности самопроверки и узнаем, как наладить скрипт, чтобы всё происходило автоматически.
#
# Для этого мы познакомимся с библиотекой pandas, которая является основным инструментом обработки данных, и научимся работать с датафрэймами.
#
# Ноутбук из лекции: [lesson_2.ipynb](https://stepik.org/media/attachments/lesson/383518/lesson_2.ipynb)
#
# Датасет из лекции: [lesson_1_data.csv](https://stepik.org/media/attachments/lesson/383514/lesson_1_data.csv)

# %% [markdown]
# ### 2.1.1 Считывание данных

# %%
df = pd.read_csv('lesson_1_data.csv', encoding='windows-1251', sep=';')

# %%
df.head() # показать первые пять записей в таблице
# Out:
#      Номер     Дата создания       Дата оплаты                        Title  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52      Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27      Курс обучения «Эксперт»
# 2  1062856  01.12.2019 21:43               NaN   Курс обучения «Специалист»
# 3  1062880   03.12.2019 0:18               NaN  Курс обучения «Консультант»
# 4  1062899  03.12.2019 21:43               NaN      Курс обучения «Эксперт»
#
#      Статус  Заработано                          Город   Платежная система
# 0  Завершен     29597.5                           Чита  Сбербанк эквайринг
# 1  Завершен     17450.3                      Краснодар        Яндекс.Касса
# 2   Отменен         0.0                            NaN                 NaN
# 3   Отменен         0.0  г.Москва и Московская область                 NaN
# 4   Отменен         0.0  г.Москва и Московская область                 NaN

# %%
df.tail() # показать последние пять записей в таблице
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 287  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен     2935.44
# 288                        Курс обучения «Консультант»   Отменен        0.00
# 289                        Курс обучения «Консультант»  Завершен     7423.92
# 290  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен     2935.44
# 291  Курс от Школы Диетологов. Повышение квалификац...  Завершен     9898.56
#
#                   Город                 Платежная система
# 287   Самарская область                      Яндекс.Касса
# 288                 NaN                               NaN
# ...

# %% [markdown]
# ### 2.1.2 Методы и атрибуты DataFrame, метод Rename

# %%
df.shape #посмотреть количество строк и колонок
# Out:
# (292, 8)

# %%
df.dtypes # отображает типы данных в колонках
# Out:
# Номер                  int64
# Дата создания         object
# Дата оплаты           object
# Title                 object
# Статус                object
# Заработано           float64
# Город                 object
# Платежная система     object
# dtype: object

# %%
df.describe() # различные показатели для количественных переменных
# Out:
#               Номер    Заработано
# count  2.920000e+02    292.000000
# mean   1.063745e+06   3397.615034
# std    4.438688e+02   5771.572829
# min    1.062823e+06      0.000000
# 25%    1.063608e+06      0.000000
# 50%    1.063698e+06   2935.440000
# 75%    1.063807e+06   2935.440000
# max    1.064796e+06  42750.000000

# %% [markdown]
# **Переименование колонок**

# %%
df.columns #отобразить список всех колонок в датафрейме
# Out:
# Index(['Номер', 'Дата создания', 'Дата оплаты', 'Title', 'Статус',
#        'Заработано', 'Город', 'Платежная система'],
#       dtype='object')

# %%
df = df.rename(columns={'Номер': 'number',
                   'Дата создания': 'create_date',
                   'Дата оплаты': 'payment_date',
                   'Title': 'title',
                   'Статус': 'status',
                   'Заработано': 'money',
                   'Город': 'city',
                   'Платежная система': 'payment_system'             
                  })

# %%
df.head(2)
# Out:
#     number       create_date      payment_date                    title  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52  Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27  Курс обучения «Эксперт»
#
#      status    money       city      payment_system
# 0  Завершен  29597.5       Чита  Сбербанк эквайринг
# 1  Завершен  17450.3  Краснодар        Яндекс.Касса

# %%
# отобразить столбцы title и create_date (столбцы надо передавать в виде списка)
df[['title', 'create_date']].head(2)
# Out:
#                      title       create_date
# 0  Курс обучения «Эксперт»  01.12.2019 10:50
# 1  Курс обучения «Эксперт»  01.12.2019 20:53

# %% [markdown]
# ### 2.1.3 Группировка, агрегация, сортировка данных

# %%
# сумма значений в колонке money
all_money = df.money.sum()
all_money
# Out:
# 992103.5900000001

# %% [markdown]
# **Группировка по title с агрегацией суммы значений в колонке money (agg = aggregate) + reset_index + сортировка по убыванию**

# %%
df.groupby(['title']).agg({'money': 'sum'}).reset_index().sort_values('money', ascending=False)
# Out:
#                                                title      money
# 5  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  366947.20
# 0                        Курс обучения «Консультант»  208163.49
# 1                         Курс обучения «Специалист»  160862.64
# 2                            Курс обучения «Эксперт»  148992.80
# 4  Курс от Школы Диетологов. Повышение квалификац...   88384.92
# 3                   Курс от Школы Диетологов. Бизнес   18752.54

# %%
# эквивалент предыдущей команды
df.groupby('title', as_index=False).agg({'money': 'sum'}).sort_values('money', ascending=False)
# более читабельный вариант записи
#df \
#    .groupby('title', as_index=False) \
#    .agg({'money': 'sum'}) \
#    .sort_values('money', ascending=False)
# Out:
#                                                title      money
# 5  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  366947.20
# 0                        Курс обучения «Консультант»  208163.49
# 1                         Курс обучения «Специалист»  160862.64
# 2                            Курс обучения «Эксперт»  148992.80
# 4  Курс от Школы Диетологов. Повышение квалификац...   88384.92
# 3                   Курс от Школы Диетологов. Бизнес   18752.54

# %% [markdown]
# **Дополнительная группировка по колонке city (колонки в groupby при этом следует оборачивать в список)**

# %%
df.groupby(['title', 'city'], as_index=False) \
    .agg({'money': 'sum'}) \
    .sort_values('money', ascending=False)
# Out:
#                                                  title  \
# 51                             Курс обучения «Эксперт»
# 156  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...
# 39                             Курс обучения «Эксперт»
# 95   Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...
# 30                          Курс обучения «Специалист»
# ..                                                 ...
# 63   Курс от Школы Диетологов. Повышение квалификац...
# 61   Курс от Школы Диетологов. Повышение квалификац...
# 55                    Курс от Школы Диетологов. Бизнес
# 54                    Курс от Школы Диетологов. Бизнес
# 158  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...
#
#                                           city     money
# 51   г.Санкт-Петербург и Ленинградская область  59195.00
# 156              г.Москва и Московская область  46967.04
# 39                                      Балхаш  42750.00
# 95                          Краснодарский край  38169.78
# ...

# %% [markdown]
# **Экспорт в формат CSV**

# %%
# сохраняем датафрейм в переменную money_by_city
money_by_city = df.groupby(['title', 'city'], as_index=False) \
                  .agg({'money': 'sum'}) \
                  .sort_values('money', ascending=False)

# %%
# index=False убирает столбец с индексом
money_by_city.to_csv('money_by_city.csv', encoding='windows-1251', index=False)

# %% [markdown]
# ### 2.1.4 Способы самопроверки при анализе данных

# %% [markdown]
# **Добавление количества заказов для каждого из курсов ('number': 'count') с условием (query), что статус "Завершен" и с переименованием колонки number в success_orders**

# %%
df \
    .query('status == "Завершен"') \
    .groupby(['title'], as_index=False) \
    .agg({'money': 'sum', 'number': 'count'}) \
    .sort_values('money', ascending=False) \
    .rename(columns={'number': 'success_orders'})
# Out:
#                                                title      money  \
# 5  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  366947.20
# 0                        Курс обучения «Консультант»  208163.49
# 1                         Курс обучения «Специалист»  160862.64
# 2                            Курс обучения «Эксперт»  148992.80
# 4  Курс от Школы Диетологов. Повышение квалификац...   88384.92
# 3                   Курс от Школы Диетологов. Бизнес   18752.54
#
#    success_orders
# 5             125
# 0              31
# 1               7
# 2               5
# 4               9
# 3               3

# %% [markdown]
# **Проверка уникальных значений курсов**

# %%
df['title'].nunique()
# Out:
# 6

# %%
df['title'].unique()
# Out:
# array(['Курс обучения «Эксперт»', 'Курс обучения «Специалист»',
#        'Курс обучения «Консультант»', 'Курс от Школы Диетологов. Бизнес',
#        'Курс от Школы Диетологов. Повышение квалификации. ',
#        'Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автосписанием'],
#       dtype=object)

# %% [markdown]
# **Проверка суммы в исходном и полученном датафреймах**

# %%
money_title = df \
    .query('status == "Завершен"') \
    .groupby(['title'], as_index=False) \
    .agg({'money': 'sum', 'number': 'count'}) \
    .sort_values('money', ascending=False) \
    .rename(columns={'number': 'success_orders'})

# %%
money_title.money.sum() # 992103.5900000003
# Out:
# 992103.5900000003

# %%
df.money.sum() # 992103.5900000001
# суммы равны, значит нет потерянных строк
# Out:
# 992103.5900000001

# %%
if int(money_title.money.sum()) == int(df.money.sum()):
    print('OK')
else:
    print('ERROR!')
# Out:
# OK

# %% [markdown]
# ### 2.1.5 Автоматизация скучной работы

# %% [markdown]
# **Автоматическое добавление сегодняшней даты к имени создаваемого файла**

# %%
#from datetime import datetime - импортирование добавлено выше в блокноте
today_day = datetime.today().strftime('%Y-%m-%d')
file_name = f'money_title_{today_day}.csv'
today_day
# Out:
# '2021-05-18'

# %%
if int(money_title.money.sum()) == int(df.money.sum()):
    print(f'OK. {file_name} is created.')
    money_title.to_csv(file_name, encoding='windows-1251', index=False)
else:
    print('ERROR!')
# Out:
# OK. money_title_2021-05-18.csv is created.

# %% [markdown]
# ## 2.2 Конспект второго урока

# %% [markdown]
# Ссылки на стэпы с кусочками конспекта из этого урока:
#
# - [Библиотека](https://stepik.org/lesson/375663/step/2?unit=363413)
# - [Считывание csv](https://stepik.org/lesson/375663/step/3?unit=363413)
# - [Атрибуты vs Методы](https://stepik.org/lesson/375663/step/4?unit=363413)
# - [Размеры датафрэйма и типы его колонок](https://stepik.org/lesson/375663/step/5?unit=363413)
# - [Метод describe и переименование колонок](https://stepik.org/lesson/375663/step/6?unit=363413)
# - [Обращение и создание колонок](https://stepik.org/lesson/375663/step/7?unit=363413)
# - [Применение вычислительных методов и цепочка из них](https://stepik.org/lesson/375663/step/8?unit=363413)
# - [Группировка и агрегация](https://stepik.org/lesson/375663/step/9?unit=363413)
# - [Сортировка значений и распределение значений](https://stepik.org/lesson/375663/step/10?unit=363413)
# - [Запросы](https://stepik.org/lesson/375663/step/11?unit=363413)
# - [Запись в файл](https://stepik.org/lesson/375663/step/12?unit=363413)
# - [Использованные в уроке функции](https://stepik.org/lesson/375663/step/13?unit=363413)
# - [Векторизация и None](https://stepik.org/lesson/375663/step/14?unit=363413)
# - [Создание функций](https://stepik.org/lesson/375663/step/15?unit=363413)
# - [Время и погрешности в арифметике](https://stepik.org/lesson/375663/step/16?unit=363413)

# %% [markdown]
# ### 2.3 Задания второго урока

# %% [markdown]
# Отлично! Теперь поработаем с данными о поездках на такси в Нью-Йорке, в которых также имеется информация о погодных условиях и выходных днях.
#
# - pickup_dt – период с точностью до часа
# - pickup_month – месяц
# - borough – район Нью-Йорка, из которого был сделан заказ (5 районов + аэропорт)
# - pickups – число поездок за период (час)
# - hday – является ли день праздничным/выходным; Y – да, N – нет
# - spd – скорость ветра в милях в час
# - vsb – видимость
# - temp – температура в градусах Фаренгейта
# - dewp – точка росы по Фаренгейту
# - slp – давление
# - pcp_01 – количество осадков за час
# - pcp_06 – количество осадков за 6 часов
# - pcp_24 – количество осадков за 24 часа
# - sd – глубина снега в дюймах
#
# Импортируйте библиотеку pandas, а затем загрузите датасет 2_taxi_nyc, находящийся [здесь](https://stepik.org/media/attachments/lesson/360340/2_taxi_nyc.csv). Результат сохраните в переменную taxi.

# %%
taxi = pd.read_csv('https://stepik.org/media/attachments/lesson/360340/2_taxi_nyc.csv')

# %%
taxi.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
taxi.shape
# Out:
# (29101, 14)

# %%
taxi.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29101 entries, 0 to 29100
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pickup_dt     29101 non-null  object
#  1   pickup_month  29101 non-null  object
#  2   borough       26058 non-null  object
#  3   pickups       29101 non-null  int64
#  4   hday          29101 non-null  object
#  5   spd           29101 non-null  float64
#  6   vsb           29101 non-null  float64
#  7   temp          29101 non-null  float64
#  8   dewp          29101 non-null  float64
#  9   slp           29101 non-null  float64
#  10  pcp 01        29101 non-null  float64
#  11  pcp 06        29101 non-null  float64
#  12  pcp 24        29101 non-null  float64
#  13  sd            29101 non-null  float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 3.1+ MB

# %%
taxi = taxi.rename(columns={'pcp 01': 'pcp_01',
                    'pcp 06': 'pcp_06',
                    'pcp 24': 'pcp_24'})

# %%
taxi.head(2)
# Out:
#              pickup_dt pickup_month   borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan     Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan  Brooklyn     1519    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
taxi['borough'].value_counts()
# Out:
# Staten Island    4343
# Queens           4343
# EWR              4343
# Bronx            4343
# Brooklyn         4343
# Manhattan        4343
# Name: borough, dtype: int64

# %%
taxi.pickups.sum()
# Out:
# 14265773

# %%
taxi\
    .groupby('borough')\
    .agg({'pickups': 'sum'})\
    .sort_values('pickups', ascending=False)
# Out:
#                 pickups
# borough
# Manhattan      10367841
# Brooklyn        2321035
# Queens          1343528
# Bronx            220047
# Staten Island      6957
# EWR                 105

# %%
taxi.groupby('borough').agg({'pickups': 'sum'}).idxmin()
# Out:
# pickups    EWR
# dtype: object

# %% [markdown]
# 10. Продолжим изучение данных и посмотрим на число поездок в выходные дни. Сгруппируйте данные по двум признакам: району города и является ли день выходным (колонки borough и hday). Сравните среднее число поездок, и выберите районы, из которых по праздникам в среднем поступает больше заказов, чем в обычные дни.

# %%
taxi\
    .groupby(['borough', 'hday'], as_index=False)\
    .agg({'pickups': 'mean'})\
    .sort_values('pickups', ascending=False)
# Out:
#           borough hday      pickups
# 6       Manhattan    N  2401.302921
# 7       Manhattan    Y  2035.928144
# 2        Brooklyn    N   534.727969
# 3        Brooklyn    Y   527.011976
# 9          Queens    Y   320.730539
# 8          Queens    N   308.899904
# 0           Bronx    N    50.771073
# 1           Bronx    Y    48.065868
# 10  Staten Island    N     1.606082
# 11  Staten Island    Y     1.497006
# 5             EWR    Y     0.041916
# 4             EWR    N     0.023467

# %% [markdown]
# 11. Для каждого района посчитайте число поездок по месяцам. Отсортируйте полученные значения по убыванию и сохраните результирующий датафрейм в **pickups_by_mon_bor**. Обратите внимание, что итоговый датасет должен состоять из трёх колонок: **pickup_month, borough, pickups**.

# %%
pickups_by_mon_bor = taxi\
    .groupby(['pickup_month', 'borough'], as_index=False)\
    .agg({'pickups': 'sum'})\
    .sort_values('pickups', ascending=False)

pickups_by_mon_bor
# Out:
#    pickup_month        borough  pickups
# 21          Jun      Manhattan  1995388
# 33          May      Manhattan  1888800
# 9           Feb      Manhattan  1718571
# 27          Mar      Manhattan  1661261
# 3           Apr      Manhattan  1648278
# 15          Jan      Manhattan  1455543
# 19          Jun       Brooklyn   482466
# 31          May       Brooklyn   476087
# 1           Apr       Brooklyn   378095
# 25          Mar       Brooklyn   346726
# 7           Feb       Brooklyn   328650
# 13          Jan       Brooklyn   309011
# 22          Jun         Queens   286311
# 34          May         Queens   275893
# 28          Mar         Queens   219561
# 4           Apr         Queens   216857
# 10          Feb         Queens   185695
# 16          Jan         Queens   159211
# 30          May          Bronx    53037
# 18          Jun          Bronx    49006
# 0           Apr          Bronx    34617
# 24          Mar          Bronx    32232
# ...

# %% [markdown]
# 12. Теперь задача посложнее! Попрактикуемся в написании собственных функций и их применении к датафрейму. Поскольку данные о поездках в Нью-Йорке, температура представлена в градусах Фаренгейта.
#
# Напишите функцию temp_to_celcius, которая получает на вход колонку с температурой в °F и возвращает значения, переведённые в градусы Цельсия.

# %%
def temp_to_celcius(temp):
    return (temp - 32) * 5 / 9

# %% [markdown]
# ### 2.4 Задания по минипроекту второго урока

# %% [markdown]
# **1. Импортируйте библиотеку pandas как pd. Загрузите датасет bookings.csv с разделителем ;. Проверьте размер таблицы, типы переменных, а затем выведите первые 7 строк, чтобы посмотреть на данные.**

# %%
df_bookings = pd.read_csv('https://stepik.org/media/attachments/lesson/360344/bookings.csv', sep=';')

# %%
df_bookings.head(3)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
#
#    Stays in Weekend nights  Stays in week nights  ...  Adults  Children  \
# 0                        0                     0  ...       2       0.0
# 1                        0                     0  ...       2       0.0
# 2                        0                     1  ...       1       0.0
#
# ...

# %%
df_bookings.shape
# Out:
# (119390, 21)

# %%
df_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Hotel                      119390 non-null  object
#  1   Is Canceled                119390 non-null  int64
#  2   Lead Time                  119390 non-null  int64
#  3   arrival full date          119390 non-null  object
#  4   Arrival Date Year          119390 non-null  int64
#  5   Arrival Date Month         119390 non-null  object
#  6   Arrival Date Week Number   119390 non-null  int64
#  7   Arrival Date Day of Month  119390 non-null  int64
#  8   Stays in Weekend nights    119390 non-null  int64
#  9   Stays in week nights       119390 non-null  int64
#  10  stays total nights         119390 non-null  int64
#  11  Adults                     119390 non-null  int64
#  12  Children                   119386 non-null  float64
# ...

# %% [markdown]
# **2. Приведите названия колонок к нижнему регистру и замените пробелы на знак нижнего подчеркивания.**

# %%
# создаем словарь с откорректированными именами колонок
#(нижний регистр + заменены пробелы на нижнее подчеркивание)
l_columns = list(df_bookings.columns)
d_col = {}
for i in range(len(l_columns)):
    d_col[l_columns[i]] = l_columns[i].lower().replace(' ', '_')
print(d_col)
# Out:
# {'Hotel': 'hotel', 'Is Canceled': 'is_canceled', 'Lead Time': 'lead_time', 'arrival full date': 'arrival_full_date', 'Arrival Date Year': 'arrival_date_year', 'Arrival Date Month': 'arrival_date_month', 'Arrival Date Week Number': 'arrival_date_week_number', 'Arrival Date Day of Month': 'arrival_date_day_of_month', 'Stays in Weekend nights': 'stays_in_weekend_nights', 'Stays in week nights': 'stays_in_week_nights', 'stays total nights': 'stays_total_nights', 'Adults': 'adults', 'Children': 'children', 'Babies': 'babies', 'Meal': 'meal', 'Country': 'country', 'Reserved Room Type': 'reserved_room_type', 'Assigned room type': 'assigned_room_type', 'customer type': 'customer_type', 'Reservation Status': 'reservation_status', 'Reservation status_date': 'reservation_status_date'}

# %%
df_bookings = df_bookings.rename(columns={
    'Hotel': 'hotel',
    'Is Canceled': 'is_canceled',
    'Lead Time': 'lead_time',
    'arrival full date': 'arrival_full_date',
    'Arrival Date Year': 'arrival_date_year',
    'Arrival Date Month': 'arrival_date_month',
    'Arrival Date Week Number': 'arrival_date_week_number',
    'Arrival Date Day of Month': 'arrival_date_day_of_month',
    'Stays in Weekend nights': 'stays_in_weekend_nights',
    'Stays in week nights': 'stays_in_week_nights',
    'stays total nights': 'stays_total_nights',
    'Adults': 'adults',
    'Children': 'children',
    'Babies': 'babies',
    'Meal': 'meal',
    'Country': 'country',
    'Reserved Room Type': 'reserved_room_type',
    'Assigned room type': 'assigned_room_type',
    'customer type': 'customer_type',
    'Reservation Status': 'reservation_status',
    'Reservation status_date': 'reservation_status_date'
})

# %%
df_bookings.head(2)
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  adults  children  \
# 0                        0                     0  ...       2       0.0
# 1                        0                     0  ...       2       0.0
#
#    babies  meal country reserved_room_type assigned_room_type customer_type  \
# 0       0    BB     PRT                  C                  C     Transient
# 1       0    BB     PRT                  C                  C     Transient
#
#   reservation_status reservation_status_date
# ...

# %% [markdown]
# **3. Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5.**

# %%
top_reserv = df_bookings \
    .query('is_canceled == 0') \
    .groupby('country', as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False) \
    .rename(columns={'is_canceled': 'reservations'})

top_reserv.head(5)
# Out:
#     country  reservations
# 125     PRT         21071
# 57      GBR          9676
# 54      FRA          8481
# 50      ESP          6391
# 42      DEU          6069

# %% [markdown]
# **4. На сколько ночей в среднем бронируют отели разных типов?**

# %%
df_bookings \
    .groupby('hotel', as_index=False) \
    .agg({'stays_total_nights': 'mean'}) \
    .round(2) \
    .rename(columns={'stays_total_nights': 'mean_nights'})
# Out:
#           hotel  mean_nights
# 0    City Hotel         2.98
# 1  Resort Hotel         4.32

# %% [markdown]
# **5. Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете?**

# %%
changed_room_type = df_bookings \
    .query('reserved_room_type != assigned_room_type')

changed_room_type.shape[0]
# Out:
# 14917

# %% [markdown]
# **6. Проанализируйте даты запланированного прибытия.**
# - **6.1 На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?**

# %%
reserv_month_2016 = df_bookings \
    .query('arrival_date_year == 2016 and is_canceled == 0') \
    .groupby('arrival_date_month', as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False) \
    .rename(columns={'is_canceled': 'reservations'})

reserv_month_2016
# Out:
#    arrival_date_month  reservations
# 10            October          3689
# 8                 May          3563
# 11          September          3372
# 0               April          3367
# 7               March          3347
# 1              August          3238
# 6                June          3196
# 5                July          3073
# 9            November          2818
# 3            February          2554
# 2            December          2462
# 4             January          1691

# %%
#месяц 2016 с наибольшим количеством успешных бронирований
list(reserv_month_2016.arrival_date_month)[0] # October
# Out:
# 'October'

# %%
reserv_month_2017 = df_bookings \
    .query('arrival_date_year == 2017 and is_canceled == 0') \
    .groupby('arrival_date_month', as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False) \
    .rename(columns={'is_canceled': 'reservations'})

reserv_month_2017
# Out:
#   arrival_date_month  reservations
# 7                May          3551
# 4               July          3329
# 6              March          3298
# 5               June          3208
# 0              April          3198
# 1             August          3109
# 2           February          2818
# 3            January          2431

# %%
#месяц 2017 с наибольшим количеством успешных бронирований
list(reserv_month_2017.arrival_date_month)[0] # May
# Out:
# 'May'

# %% [markdown]
# - **6.2 Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов.**

# %%
# Способ № 1
df_bookings \
    .query('is_canceled == 1 and hotel == "City Hotel"') \
    .groupby(['arrival_date_year', 'arrival_date_month'], as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#     arrival_date_year arrival_date_month  is_canceled
# 25               2017                May         2217
# 16               2016            October         1947
# 18               2017              April         1926
# 23               2017               June         1808
# 12               2016               June         1720
# 17               2016          September         1567
# 5                2015          September         1543
# 6                2016              April         1539
# 14               2016                May         1436
# 15               2016           November         1360
# 22               2017               July         1324
# 4                2015            October         1321
# 24               2017              March         1278
# 7                2016             August         1247
# 0                2015             August         1232
# 19               2017             August         1123
# ...

# %%
# Способ № 2
df_bookings \
    .query('is_canceled == 1') \
    .groupby(['hotel', 'arrival_date_year', 'arrival_date_month'], as_index=False) \
    .agg({'is_canceled': 'count'}) \
    .sort_values('is_canceled', ascending=False)
# Out:
#            hotel  arrival_date_year arrival_date_month  is_canceled
# 25    City Hotel               2017                May         2217
# 16    City Hotel               2016            October         1947
# 18    City Hotel               2017              April         1926
# 23    City Hotel               2017               June         1808
# 12    City Hotel               2016               June         1720
# 17    City Hotel               2016          September         1567
# 5     City Hotel               2015          September         1543
# 6     City Hotel               2016              April         1539
# 14    City Hotel               2016                May         1436
# 15    City Hotel               2016           November         1360
# 22    City Hotel               2017               July         1324
# 4     City Hotel               2015            October         1321
# 24    City Hotel               2017              March         1278
# ...

# %%
# Способ №3 (из видео разбора)
# скобки позволяют осуществлять перенос строк без '\'
(
    df_bookings
        .query('hotel == "City Hotel" and is_canceled == 1')
        .groupby('arrival_date_year')
        .arrival_date_month
        .value_counts()
)
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             1543
#                    October               1321
#                    August                1232
#                    July                   939
#                    December               668
#                    November               301
# 2016               October               1947
#                    June                  1720
#                    September             1567
#                    April                 1539
#                    May                   1436
#                    November              1360
#                    August                1247
#                    March                 1108
#                    December              1072
#                    July                  1043
#                    February               930
#                    January                438
# 2017               May                   2217
#                    April                 1926
# ...

# %% [markdown]
# **7. Посмотрите на числовые характеристики трёх переменных: adults, children и babies. Какая из них имеет наибольшее среднее значение?**

# %%
# Способ №1
df_bookings \
    .agg({'adults': 'mean', 'children': 'mean', 'babies': 'mean'})
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
# Способ №2 (из видео разбора)
df_bookings[['adults', 'children', 'babies']].describe()
# Out:
#               adults       children         babies
# count  119390.000000  119386.000000  119390.000000
# mean        1.856403       0.103890       0.007949
# std         0.579261       0.398561       0.097436
# min         0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         2.000000       0.000000       0.000000
# max        55.000000      10.000000      10.000000

# %%
# Способ №3 (из видео разбора)
df_bookings[['adults', 'children', 'babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %% [markdown]
# **8. Создайте колонку total_kids, объединив children и babies. Отели какого типа в среднем пользуются большей популярностью у клиентов с детьми?**

# %%
# Способ №1
df_kids = df_bookings[['hotel','is_canceled', 'children', 'babies']]
df_kids.head(2)
# Out:
#           hotel  is_canceled  children  babies
# 0  Resort Hotel            0       0.0       0
# 1  Resort Hotel            0       0.0       0

# %%
df_kids['total_kids'] = df_kids.loc[:, ('children', 'babies')].sum(axis=1)
df_kids.head(2)
# Out:
# <ipython-input-133-5b24aa47c432>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kids['total_kids'] = df_kids.loc[:, ('children', 'babies')].sum(axis=1)
#           hotel  is_canceled  children  babies  total_kids
# 0  Resort Hotel            0       0.0       0         0.0
# 1  Resort Hotel            0       0.0       0         0.0

# %%
(
    df_kids
        .groupby('hotel', as_index=False)
        .agg({'total_kids': 'mean'})
        .round(2)
        .sort_values('total_kids', ascending=False)
        .rename(columns={'total_kids': 'mean_kids'})
)
# Out:
#           hotel  mean_kids
# 1  Resort Hotel       0.14
# 0    City Hotel       0.10

# %%
# Способ №2 (из видео разбора)
df_kids_2 = df_bookings[['hotel', 'children', 'babies']]
df_kids_2['total_kids'] = df_kids_2['children'] + df_kids_2['babies']
# Out:
# <ipython-input-122-7a172130d480>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kids_2['total_kids'] = df_kids_2['children'] + df_kids_2['babies']

# %%
(
    df_kids_2
        .groupby('hotel', as_index=False)
        .agg({'total_kids': 'mean'})
        .round(2)
        .max()
)
# Out:
# hotel         Resort Hotel
# total_kids            0.14
# dtype: object

# %% [markdown]
# **9. Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), и False – в противном случае. Посчитайте отношение количества ушедших пользователей к общему количеству клиентов, выраженное в процентах (churn rate). Укажите, среди какой группы показатель выше.**

# %%
# мой вариант: df_kids['has_kids'] = [True if i > 0 else False for i in df_kids['total_kids']]
df_kids['has_kids'] = df_kids['total_kids'] > 0 # вариант из видео обзора
df_kids.head()
# Out:
# <ipython-input-194-a53a837bd7e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kids['has_kids'] = df_kids['total_kids'] > 0
#           hotel  is_canceled  children  babies  total_kids  has_kids
# 0  Resort Hotel            0       0.0       0         0.0     False
# 1  Resort Hotel            0       0.0       0         0.0     False
# 2  Resort Hotel            0       0.0       0         0.0     False
# 3  Resort Hotel            0       0.0       0         0.0     False
# 4  Resort Hotel            0       0.0       0         0.0     False

# %%
canc_with_kids = (
    df_kids
        .query('is_canceled == 1 and has_kids == True')
        .shape[0]
)

# %%
with_kids = (
    df_kids
        .query('has_kids == True')
        .shape[0]
)

# %%
canc_without_kids = (
    df_kids
        .query('is_canceled == 1 and has_kids == False')
        .shape[0]
)

# %%
without_kids = (
    df_kids
        .query('has_kids == False')
        .shape[0]
)

# %%
canc_with_kids_ratio = round(100 * canc_with_kids/with_kids, 2)

# %%
canc_without_kids_ratio = round(100 * canc_without_kids/without_kids, 2)

# %%
print(max(canc_with_kids_ratio, canc_without_kids_ratio))
# Out:
# 37.22

# %%
# Еще один способ с использованием normalize=True
(
    df_kids
        .groupby('has_kids')
        .is_canceled
        .value_counts(normalize=True)
)
# Out:
# has_kids  is_canceled
# False     0              0.627787
#           1              0.372213
# True      0              0.650772
#           1              0.349228
# Name: is_canceled, dtype: float64

# %% [markdown]
# ## 3 Третий урок python для работы с данными

# %% [markdown]
# ### 3.1 Лекция третьего урока
#
# Сегодня мы займёмся более подробным решением аналитических задач – с эксплоративным анализом данных, созданием метрик и анализом распределений. Мы познакомимся с объединением датафрэймов и применением функций к колонкам датафрэйма. Также освоим новые методы, посмотрим на пандасовские серии и научимся создавать анонимные функции. Кроме того, на этом уроке мы начнём визуализировать данные :)
#
# Ноутбук из лекции: [lesson_3.ipynb](https://stepik.org/media/attachments/lesson/383523/lesson_3.ipynb)\
# Датасет из лекции: [lesson_3_data.csv](https://stepik.org/media/attachments/lesson/383523/lesson_3_data__1_.csv)

# %%
df_lesson3 = pd.read_csv('lesson_3_data.csv', encoding='windows-1251')

# %% [markdown]
# **3.2. Предподготовка данных**

# %%
df_lesson3.head(2)
# Out:
#    Unnamed: 0                  tk  pl         dia        hs         tc  \
# 0        1242  120071109002055793   1  2007/11/09  0.505729  110000761
# 1        1243  120070601004053633   1  2007/06/01  0.588519  110000761
#
#         cta  id_art  id_subsubfam   id_subfam  ...   id_famn  id_seccion  \
# 0  11000076   21895  101070640100  1010706401  ...  10107064       10107
# 1  11000076   21816  101070640100  1010706401  ...  10107064       10107
#
#    id_subagr  id_agr   vta  uni  id_artn                              art_sp  \
# 0        101       1  0.68  1.0    21895  MARAVILLA        500 G Store_Brand
# 1        101       1  0.38  1.0    21816  FIDEO CABELLIN   500 G Store_Brand
#
#                  fam_sp fam_en
# 0  PASTA ALIMENTICIA SE  pasta
# 1  PASTA ALIMENTICIA SE  pasta
#
# [2 rows x 21 columns]

# %%
df_lesson3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48129 entries, 0 to 48128
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    48129 non-null  int64
#  1   tk            48129 non-null  object
#  2   pl            48129 non-null  int64
#  3   dia           48129 non-null  object
#  4   hs            48129 non-null  float64
#  5   tc            48129 non-null  int64
#  6   cta           48129 non-null  int64
#  7   id_art        48129 non-null  int64
#  8   id_subsubfam  48129 non-null  int64
#  9   id_subfam     48129 non-null  int64
#  10  id_fam        48129 non-null  int64
#  11  id_famn       48129 non-null  int64
#  12  id_seccion    48129 non-null  int64
#  13  id_subagr     48129 non-null  int64
#  14  id_agr        48129 non-null  int64
#  15  vta           48129 non-null  float64
#  16  uni           48129 non-null  float64
#  17  id_artn       48129 non-null  int64
# ...

# %%
user_df = df_lesson3[['tc', 'art_sp']]

# %%
user_df = user_df.rename(columns={'tc': 'user_id',
                       'art_sp': 'brand_info'})

# %%
user_df.head(2)
# Out:
#      user_id                          brand_info
# 0  110000761  MARAVILLA        500 G Store_Brand
# 1  110000761  FIDEO CABELLIN   500 G Store_Brand

# %% [markdown]
# **3.3. Метод apply для трансформации колонок**

# %%
k = 'MARAVILLA 500 G Store_Brand'

# %%
print(k[k.rfind(' ') + 1:])
# Out:
# Store_Brand

# %%
print(k.split()[-1])
# Out:
# Store_Brand

# %% [markdown]
# **3.4. Lambda функции для быстрых вычислений**

# %%
# лямбда функция, чтобы разрезать строку по пробелу и оставить последнюю часть строки brand_info
user_df['brand_name'] = user_df.brand_info.apply(lambda brand_info: brand_info.split()[-1])

# %%
user_df.head(2)
# Out:
#      user_id                          brand_info   brand_name
# 0  110000761  MARAVILLA        500 G Store_Brand  Store_Brand
# 1  110000761  FIDEO CABELLIN   500 G Store_Brand  Store_Brand

# %% [markdown]
# **3.5. Приступаем к аналитике**

# %%
# подсчет покупок каждым пользователем
users_purchases_test = (
    user_df
        .groupby('user_id', as_index=False)
        .agg({'brand_name': 'count'})
        .rename(columns={'brand_name': 'purchases'})
)

# %%
users_purchases_test.head()
# Out:
#       user_id  purchases
# 0 -1236394515          1
# 1        1031          6
# 2        4241          5
# 3       17311          2
# 4       17312          2

# %%
users_purchases_test.shape
# Out:
# (11764, 2)

# %%
# медианное количество покупок пользователей
users_purchases_test.purchases.median()
# Out:
# 2.0

# %%
users_purchases_test.describe()
# Out:
#             user_id     purchases
# count  1.176400e+04  11764.000000
# mean   7.690517e+07      4.091210
# std    1.622210e+08      4.573143
# min   -1.236395e+09      1.000000
# 25%    1.503761e+07      1.000000
# 50%    4.682179e+07      2.000000
# 75%    9.311601e+07      5.000000
# max    1.408849e+09     60.000000

# %%
# оставляем пользователей с числом покупок больше 5
users_purchases = (
    user_df
        .groupby('user_id', as_index=False)
        .agg({'brand_name': 'count'})
        .rename(columns={'brand_name': 'purchases'})
        .query('purchases >= 5')
)

# %%
users_purchases.head()
# Out:
#     user_id  purchases
# 1      1031          6
# 2      4241          5
# 11    25971          7
# 14    40911         27
# 16    45181          5

# %%
users_purchases.describe()
# Out:
#             user_id    purchases
# count  3.383000e+03  3383.000000
# mean   6.421500e+07     9.320130
# std    1.504830e+08     5.623993
# min    1.031000e+03     5.000000
# 25%    8.871271e+06     6.000000
# 50%    2.842547e+07     7.000000
# 75%    8.542964e+07    11.000000
# max    1.408810e+09    60.000000

# %%
(
user_df
    .groupby(['user_id', 'brand_name'], as_index=False)
    .agg({'brand_info': 'count'})
    .sort_values(['user_id', 'brand_info'], ascending=[False, False])
)
# Out:
#           user_id   brand_name  brand_info
# 18187  1408849249  Store_Brand           1
# 18186  1408840919  Store_Brand           1
# 18185  1408832719      Brand_4           3
# 18184  1408825059      Brand_1           1
# 18183  1408817589  Store_Brand           2
# ...           ...          ...         ...
# 3            4241      Brand_4           3
# 4            4241  Store_Brand           2
# 2            1031  Store_Brand           5
# 1            1031      Brand_3           1
# 0     -1236394515      Brand_4           1
#
# [18188 rows x 3 columns]

# %%
(
user_df
    .groupby(['user_id', 'brand_name'], as_index=False)
    .agg({'brand_info': 'count'})
    .sort_values(['user_id', 'brand_info'], ascending=[False, False])
    .groupby('user_id')
    .head(1)
)
# Out:
#           user_id   brand_name  brand_info
# 18187  1408849249  Store_Brand           1
# 18186  1408840919  Store_Brand           1
# 18185  1408832719      Brand_4           3
# 18184  1408825059      Brand_1           1
# 18183  1408817589  Store_Brand           2
# ...           ...          ...         ...
# 6           17312      Brand_1           1
# 5           17311      Brand_4           2
# 3            4241      Brand_4           3
# 2            1031  Store_Brand           5
# 0     -1236394515      Brand_4           1
#
# [11764 rows x 3 columns]

# %%
lovely_brand_purchases = (
user_df
    .groupby(['user_id', 'brand_name'], as_index=False)
    .agg({'brand_info': 'count'})
    .sort_values(['user_id', 'brand_info'], ascending=[False, False])
    .groupby('user_id')
    .head(1)
    .rename(columns={'brand_name': 'lovely_brand', 'brand_info': 'lovely_brand_purchases'})
)

# %%
lovely_brand_purchases.head()
# Out:
#           user_id lovely_brand  lovely_brand_purchases
# 18187  1408849249  Store_Brand                       1
# 18186  1408840919  Store_Brand                       1
# 18185  1408832719      Brand_4                       3
# 18184  1408825059      Brand_1                       1
# 18183  1408817589  Store_Brand                       2

# %%
# количество покупок уникальных брендов каждым пользователем
users_unique_brands = (
user_df
    .groupby('user_id', as_index=False)
    .agg({'brand_name': 'nunique'})
    .rename(columns={'brand_name': 'unique_brands'})
)

# %%
users_unique_brands.head()
# Out:
#       user_id  unique_brands
# 0 -1236394515              1
# 1        1031              2
# 2        4241              2
# 3       17311              1
# 4       17312              2

# %% [markdown]
# **3.6. Объединение данных, метод merge**
#
# [Статьи](https://habr.com/ru/post/448072/) по [джойнам](https://habr.com/ru/post/450528/), о которых говорит Анатолий!

# %%
# объединяем датафреймы users_purchases, lovely_brand_purchases, users_unique_brands

# %%
??pd.DataFrame.merge # посмотреть как работает метод merge

# %%
(
users_purchases
    .merge(users_unique_brands, on='user_id')
    .merge(lovely_brand_purchases, on='user_id')
)
# Out:
#          user_id  purchases  unique_brands lovely_brand  \
# 0           1031          6              2  Store_Brand
# 1           4241          5              2      Brand_4
# 2          25971          7              2  Store_Brand
# 3          40911         27              5      Brand_4
# 4          45181          5              4  Store_Brand
# ...          ...        ...            ...          ...
# 3378  1408767189          5              1      Brand_4
# 3379  1408783189         10              2  Store_Brand
# 3380  1408783379          6              2      Brand_1
# 3381  1408798879          8              3  Store_Brand
# 3382  1408810219          9              2      Brand_2
#
#       lovely_brand_purchases
# 0                          5
# 1                          3
# 2                          5
# 3                         19
# 4                          2
# ...                      ...
# 3378                       5
# 3379                       8
# ...

# %% [markdown]
# **3.7. От данных к метрикам**

# %%
loyalty_df = (
users_purchases
    .merge(users_unique_brands, on='user_id')
    .merge(lovely_brand_purchases, on='user_id')
)

# %%
loyalty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3383 entries, 0 to 3382
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 3383 non-null   int64
#  1   purchases               3383 non-null   int64
#  2   unique_brands           3383 non-null   int64
#  3   lovely_brand            3383 non-null   object
#  4   lovely_brand_purchases  3383 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 158.6+ KB

# %%
loyalty_df.head(3)
# Out:
#    user_id  purchases  unique_brands lovely_brand  lovely_brand_purchases
# 0     1031          6              2  Store_Brand                       5
# 1     4241          5              2      Brand_4                       3
# 2    25971          7              2  Store_Brand                       5

# %%
# отображение пользователей, которые делали покупки только одного бренда
loyalty_df[loyalty_df.unique_brands == 1]
# Out:
#          user_id  purchases  unique_brands lovely_brand  \
# 13         86281         14              1      Brand_4
# 18         94961          6              1      Brand_4
# 29        132061          9              1      Brand_4
# 30        134281          6              1      Brand_4
# 35        157311         12              1      Brand_4
# ...          ...        ...            ...          ...
# 3372  1010244089          9              1  Store_Brand
# 3374  1010247239          5              1      Brand_4
# 3376  1010274559          5              1      Brand_4
# 3377  1110091379          5              1      Brand_1
# 3378  1408767189          5              1      Brand_4
#
#       lovely_brand_purchases
# 13                        14
# 18                         6
# 29                         9
# 30                         6
# 35                        12
# ...                      ...
# 3372                       9
# 3374                       5
# ...

# %%
loyalty_df['loyalty_score'] = loyalty_df['lovely_brand_purchases'] / loyalty_df['purchases']

# %%
#loyalty_df = loyalty_df.drop(columns=['percent'])

# %%
loyalty_df.head(3)
# Out:
#    user_id  purchases  unique_brands lovely_brand  lovely_brand_purchases  \
# 0     1031          6              2  Store_Brand                       5
# 1     4241          5              2      Brand_4                       3
# 2    25971          7              2  Store_Brand                       5
#
#    loyalty_score
# 0       0.833333
# 1       0.600000
# 2       0.714286

# %% [markdown]
# **3.8. Визуализация как метод исследования данных**

# %%
ax = sns.distplot(loyalty_df.loyalty_score, kde=False)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
loyalty_df.loyalty_score.median()
# Out:
# 0.8

# %%
brands_loyalty = (
loyalty_df
    .groupby('lovely_brand', as_index=False)
    .agg({'loyalty_score': 'median', 'user_id': 'count'})
    .sort_values('loyalty_score')
)

# %%
brands_loyalty
# Out:
#   lovely_brand  loyalty_score  user_id
# 5      Brand_7       0.444444        9
# 2      Brand_3       0.500000      115
# 1      Brand_2       0.600000       88
# 4      Brand_5       0.600000        5
# 0      Brand_1       0.679487      410
# 6  Store_Brand       0.750000      715
# 3      Brand_4       0.818182     2041

# %%
ax = sns.barplot(x='lovely_brand', y='loyalty_score', data=brands_loyalty)

# %%
ax = sns.barplot(x='lovely_brand', y='user_id', data=brands_loyalty)

# %% [markdown]
# ### 3.2 Конспект третьего урока
#
# Ссылки на стэпы с кусочками конспекта из этого урока:
#
# 1. [Уникальные значения в колонке](https://stepik.org/lesson/375667/step/2?unit=363417)
# 2. [Число уникальных значений]()
# 3. [Медиана и среднее]()
# 4. [Разделение строк]()
# 5. [Анонимные функции]()
# 6. [Серии]()
# 7. [Применение функций к датафрэйму]()
# 8. [Объединение датафрэймов]()
# 9. [Индекс и колонки]()
# 10. [Сброс индекса]()
# 11. [Поиск пропущенных значений]()
# 12. [Графики]()
# 13. [pandas]()
# 14. [seaborn]()
# 15. [matplotlib]()

# %%
list(pd.unique(pd.Series([2, 1, 3, 3])))
#array([2, 1, 3])
# Out:
# [2, 1, 3]

# %% [markdown]
# ### 3.3 Задания третьего урока

# %% [markdown]
# **1**

# %%
names = 'Name1 Surname1, Name2 Surname2, Name3 Surname3'
names_list = names.split(', ')
names_list
# Out:
# ['Name1 Surname1', 'Name2 Surname2', 'Name3 Surname3']

# %% [markdown]
# **2**

# %%
df = pd.DataFrame({'client_id': [9002, 6722, 8799, 8737, 5208], \
                   'sex': [1, 1, 1, 0, 0], \
                   'wealth': ['medium', 'high', 'high', 'low', 'medium'], \
                   'age': [63, 54, 52, 54, 37]})

# %%
df
# Out:
#    client_id  sex  wealth  age
# 0       9002    1  medium   63
# 1       6722    1    high   54
# 2       8799    1    high   52
# 3       8737    0     low   54
# 4       5208    0  medium   37

# %%
df.query('wealth == "medium" and age > 35')
# Out:
#    client_id  sex  wealth  age
# 0       9002    1  medium   63
# 4       5208    0  medium   37

# %% [markdown]
# **3**

# %%
df = df.rename(columns={'Клиент id': 'client_id',
                       'Пол': 'sex',
                       'Благосостояние': 'wealth',
                       'Возраст': 'age'})

# %% [markdown]
# **4**

# %%
df['older_than_30'] = df['age'] > 30
df.head(2)
# Out:
#    client_id  sex  wealth  age  older_than_30
# 0       9002    1  medium   63           True
# 1       6722    1    high   54           True

# %% [markdown]
# **5**

# %%
unique_num = df.nunique()
unique_num
# Out:
# client_id        5
# sex              2
# wealth           3
# age              4
# older_than_30    1
# dtype: int64

# %% [markdown]
# **6**

# %%
df = pd.DataFrame({
    'client_id': [5392, 9581, 7250, 8619, 6573],
    'sex': [0, 1, 1, 0, 0],
    'wealth': ['medium', 'high', 'low', 'medium', 'high'],
    'age': [42, 34, 18, 36, 21]
})

# %%
data = pd.DataFrame({
    'client_id': [5392, 9581, 7250, 8619, 6573],
    'amount': [42331, 88420, 1714, 80572, 57549],
    'date': [1585425830, 1585425831, 1585425832, 1585425833, 1585425834]
})

# %%
(
df
    .merge(data, on='client_id')
)
# Out:
#    client_id  sex  wealth  age  amount        date
# 0       5392    0  medium   42   42331  1585425830
# 1       9581    1    high   34   88420  1585425831
# 2       7250    1     low   18    1714  1585425832
# 3       8619    0  medium   36   80572  1585425833
# 4       6573    0    high   21   57549  1585425834

# %%
full_data = (
df
    .merge(data, on='client_id')
)

# %% [markdown]
# **7**

# %%
def read_n_agg(path):
    read_n_agg = pd.read_csv(path, sep=';')
    return read_n_agg.groupby('company', as_index=True).agg({'income': 'mean'})

# %%
read_n_agg('https://stepik.org/media/attachments/lesson/359209/companies.csv')
# Out:
#                                                 income
# company
# En +                                      9.962187e+10
# АО «Александрова, Савельев и Мельникова»  7.206782e+10
# АО «Андреев-Анисимов»                     6.931948e+09
# АО «Андреев-Макарова»                     8.934380e+10
# АО «Большаков Кошелева»                   7.860861e+10
# ...                                                ...
# Щекиноазот                                4.309092e+10
# Щукин Лимитед                             6.703036e+10
# Эйвон Бьюти Продактс Компани (Avon)       2.503657e+10
# Яковлева Инкорпорэйтед                    3.523436e+10
# Якушев Лимитед                            3.876468e+10
#
# [289 rows x 1 columns]

# %% [markdown]
# **8**

# %%
df_taxi8 = pd.read_csv('https://stepik.org/media/attachments/lesson/359240/taxi_peru.csv', sep=';', parse_dates = ['start_at', 'end_at', 'arrived_at'])

# %%
df_taxi8.head()
# Out:
#                          journey_id                           user_id  \
# 0  23a1406fc6a11d866e3c82f22eed4d4c  0e9af5bbf1edfe591b54ecdfd7e91e26
# 1  dd2af4715d0dc16eded53afc0e243577  a553c46e3a22fb9c326aeb3d72b3334e
# 2  dd91e131888064bf7df3ce08f3d4b4ad  a553c46e3a22fb9c326aeb3d72b3334e
# 3  dd2af4715d0dc16eded53afc0e2466d0  a553c46e3a22fb9c326aeb3d72b3334e
# 4  85b7eabcf5d84e42dc7629b7d27781af  56772d544fdfa589a020a1ff894a86f7
#
#                           driver_id                           taxi_id  \
# 0  583949a89a9ee17d19e3ca4f137b6b4c  b12f4f09c783e29fe0d0ea624530db56
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4  d665fb9f75ef5d9cd0fd89479380ba78  0accdd3aa5a322f4129fa20b53278c69
#
#         icon start_type            start_at     start_lat     start_lon  \
# ...

# %%
df_taxi8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23111 entries, 0 to 23110
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   journey_id        23111 non-null  object
#  1   user_id           23111 non-null  object
#  2   driver_id         19726 non-null  object
#  3   taxi_id           19726 non-null  object
#  4   icon              23111 non-null  object
#  5   start_type        23111 non-null  object
#  6   start_at          23111 non-null  datetime64[ns]
#  7   start_lat         23111 non-null  object
#  8   start_lon         23111 non-null  object
#  9   end_at            22835 non-null  datetime64[ns]
#  10  end_lat           23111 non-null  object
#  11  end_lon           23111 non-null  object
#  12  end_state         23099 non-null  object
#  13  driver_start_lat  19621 non-null  object
#  14  driver_start_lon  19621 non-null  object
# ...

# %% [markdown]
# **9**

# %%
(
df_taxi8
    .groupby('source', as_index=False)
    .agg({'journey_id': 'count'})
    .sort_values('journey_id', ascending=False)
    .rename(columns={'journey_id': 'journey_amount'})
)
# Out:
#     source  journey_amount
# 3   iPhone            9741
# 4      web            7631
# 0  Android            4909
# 2     iPad             571
# 1      Wap             136

# %%
source_max = (
df_taxi8
    .groupby('source', as_index=False)
    .agg({'journey_id': 'count'})
    .sort_values('journey_id', ascending=False)
    .rename(columns={'journey_id': 'journey_amount'})
    .max()[1]
)

# %%
source_sum = (
df_taxi8
    .groupby('source', as_index=False)
    .agg({'journey_id': 'count'})
    .sort_values('journey_id', ascending=False)
    .rename(columns={'journey_id': 'journey_amount'})
    .sum()[1]
)

# %%
round(100 * source_max / source_sum, 0)
# Out:
# 42.0

# %%
# альтернативный способ
(
df_taxi8
    .source
    .value_counts(normalize=True)
    .mul(100)
    .round()
)
# Out:
# iPhone     42.0
# web        33.0
# Android    21.0
# iPad        2.0
# Wap         1.0
# Name: source, dtype: float64

# %% [markdown]
# **10**

# %%
(
df_taxi8
    .groupby('driver_score', as_index=False)
    .agg({'driver_score': 'count'})
)
# Out:
#    driver_score
# 0          1094
# 1            94
# 2            62
# 3           227
# 4          1674
# 5          4499

# %%
driver_score_counts = (
df_taxi8
    .driver_score
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
    .reset_index()
    .rename(columns={'index': 'driver_score', 'driver_score': 'percentage'})
    .sort_values('driver_score')
)

driver_score_counts
# Out:
#    driver_score  percentage
# 2           0.0       14.30
# 4           1.0        1.23
# 5           2.0        0.81
# 3           3.0        2.97
# 1           4.0       21.88
# 0           5.0       58.81

# %% [markdown]
# **11**

# %%
# alpha - прозрачность
# также допустимо x=driver_score_counts.driver_score, y=driver_score_counts.percentage
ax = sns.barplot(x='driver_score', y='percentage', data=driver_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='Driver score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %% [markdown]
# **12**

# %%
rider_score_counts = (
df_taxi8
    .rider_score
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
    .reset_index()
    .rename(columns={'index': 'rider_score', 'rider_score': 'percentage'})
    .sort_values('rider_score')
)

rider_score_counts
# Out:
#    rider_score  percentage
# 2          0.0        2.29
# 4          1.0        0.21
# 5          2.0        0.19
# 3          3.0        1.38
# 1          4.0        8.83
# 0          5.0       87.10

# %%
ax = sns.barplot(x='rider_score', y='percentage', data=rider_score_counts, color='blue', alpha=0.5)
ax.set(xlabel='Rider score', ylabel='Percentage')
sns.despine()  # убрать часть рамки графика
plt.show()

# %% [markdown]
# ### 3.4 Задания по минипроекту третьего урока

# %% [markdown]
# **1. Импортируйте библиотеку pandas как pd. Загрузите два датасета user_data и logs. Проверьте размер таблицы, типы переменных, наличие пропущенных значений, описательную статистику.**

# %%
user_data = pd.read_csv('https://stepik.org/media/attachments/lesson/360348/user_data.csv')

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2954 entries, 0 to 2953
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   client   2954 non-null   int64
#  1   premium  2954 non-null   bool
#  2   age      2954 non-null   int64
# dtypes: bool(1), int64(2)
# memory usage: 49.2 KB

# %%
user_data.head()
# Out:
#    client  premium  age
# 0   46346    False   58
# 1    4391    False   55
# 2   27372    False   64
# 3   11989    False   44
# 4   60664    False   49

# %%
logs = pd.read_csv('https://stepik.org/media/attachments/lesson/360348/logs.csv')

# %%
logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   client    4500 non-null   int64
#  1   success   4500 non-null   bool
#  2   platform  4500 non-null   object
#  3   time      4500 non-null   int64
# dtypes: bool(1), int64(2), object(1)
# memory usage: 110.0+ KB

# %%
logs.head()
# Out:
#    client  success  platform        time
# 0   40177     True     phone  1585412212
# 1   61468     True     phone  1585425658
# 2   35604    False     phone  1585459894
# 3    9961     True     phone  1585400189
# 4   10931     True  computer  1585468629

# %%
logs.platform.nunique()
# Out:
# 3

# %% [markdown]
# **2. Какой клиент совершил больше всего успешных операций? (success == True)**

# %%
top_success_clients = (
logs
    .query('success == True')
    .client
    .value_counts()
    .reset_index()
    .rename(columns={'index': 'client', 'client': 'amount'})
)

# %%
top_success_clients.head()
# Out:
#    client  amount
# 0   36165      41
# 1   61468      41
# 2   12179      41
# 3   61473      41
# 4   78349      41

# %%
# максимальное количество успешных действий среди пользователей
max_success = top_success_clients.amount.max()
max_success # 41
# Out:
# 41

# %%
# для обращения к внешней переменной в query необходимо добавить @ перед именем переменной
top_success_clients_list = (
top_success_clients
    .query('amount == @max_success')
    .client
    .sort_values(ascending=True)
    .tolist()
)

# %%
str(top_success_clients_list)[1:-1]
# Out:
# '12179, 28719, 36165, 52870, 61468, 61473, 78349, 82563, 92584'

# %%
', '.join([str(i) for i in top_success_clients_list])
# Out:
# '12179, 28719, 36165, 52870, 61468, 61473, 78349, 82563, 92584'

# %% [markdown]
# **3. С какой платформы осуществляется наибольшее количество успешных операций?**

# %%
(
logs
    .query('success == True')
    .platform
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
    .reset_index()
    .rename(columns={'index': 'platform', 'platform': 'percent'})
)
# Out:
#    platform  percent
# 0     phone    61.39
# 1  computer    33.14
# 2    tablet     5.47

# %% [markdown]
# **4. Какую платформу предпочитают премиальные клиенты?**

# %%
platform_premium = (
logs
    .merge(user_data, on='client')
)

# %%
platform_premium.head()
# Out:
#    client  success  platform        time  premium  age
# 0   61468     True     phone  1585425658    False   25
# 1   61468     True  computer  1585460504    False   25
# 2   61468     True  computer  1585430291    False   25
# 3   61468     True  computer  1585444317    False   25
# 4   61468     True     phone  1585441266    False   25

# %%
(
platform_premium
    .query('premium == True')
    .platform
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
    .reset_index()
    .rename(columns={'index': 'platform', 'platform': 'percent'})
)
# Out:
#    platform  percent
# 0     phone    58.57
# 1  computer    35.71
# 2    tablet     5.71

# %% [markdown]
# **5. Визуализируйте распределение возраста клиентов в зависимости от типа клиента (премиум или нет)**

# %%
sns.distplot(user_data.query('premium == False').age)
sns.distplot(user_data.query('premium == True').age)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
age_premium = (
user_data
    .groupby('premium', as_index=False)
    .agg({'age': 'mean', 'client': 'count'})
    .sort_values('age')
)
age_premium
# Out:
#    premium        age  client
# 0    False  44.148352    2548
# 1     True  44.495074     406

# %%
ax = sns.barplot(x='premium', y='age', data=age_premium)

# %%
brands_loyalty = (
loyalty_df
    .groupby('lovely_brand', as_index=False)
    .agg({'loyalty_score': 'median', 'user_id': 'count'})
    .sort_values('loyalty_score')
)

# %%
ax = sns.barplot(x='lovely_brand', y='loyalty_score', data=brands_loyalty)

# %% [markdown]
# **6. Постройте график распределения числа успешных операций**

# %%
success_operations2 = (
logs
    .groupby('client')
    .agg({'success': 'sum'})
)
success_operations2.head()
# Out:
#         success
# client
# 40            1
# 50            1
# 75            1
# 81            1
# 132           1

# %%
sns.distplot(success_operations2)
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
success_operations2.value_counts('success')
# Out:
# success
# 1     2791
# 0     1166
# 2       43
# 41       9
# 40       1
# 3        1
# dtype: int64

# %% [markdown]
# **7. Визуализируйте число успешных операций, сделанных на платформе computer, в зависимости от возраста, используя sns.countplot (x – возраст, y – число успешных операций). Клиенты какого возраста совершили наибольшее количество успешных действий?**

# %%
platform_computer = (
platform_premium
    .query('platform == "computer"')
    .groupby(['success', 'age'], as_index=False)
    .agg({'client': 'count'})
)

# %%
platform_computer.head(3)
# Out:
#    success  age  client
# 0    False   20       8
# 1    False   21       5
# 2    False   22       4

# %%
plt.figure(figsize=(12, 8))
ax = sns.barplot(x='age', y='client', data=platform_computer)

# %%
# из видео разбора
age_vs_success_number = (platform_premium
                            .query('platform == "computer" and success == True')
                         )

# %%
age_vs_success_number.head()
# Out:
#     client  success  platform        time  premium  age
# 1    61468     True  computer  1585460504    False   25
# 2    61468     True  computer  1585430291    False   25
# 3    61468     True  computer  1585444317    False   25
# 7    61468     True  computer  1585416826    False   25
# 11   61468     True  computer  1585428874    False   25

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='age', data=age_vs_success_number)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
x = 3
6 * (x ** 2) - 2 * x
# Out:
# 48
